# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
#
# This notebook has two parts. In the first part, you will scrape lyrics from AZLyrics.com. In the second part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 20 songs with lyrics on AZLyrics.com. We start with pulling some information and analyzing them.

# %% [markdown]
# # Importing Libraries

# %%
import os
import datetime
import re

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import random

# %%
# Use this cell for any import statements you add

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data by scraping www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
artists = {'one direction':"https://www.azlyrics.com/o/onedirection.html",
           'sabrina carpenter':"https://www.azlyrics.com/s/sabrinacarpenter.html"} 
# we'll use this dictionary to hold both the artist name and the link on AZlyrics

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# A: The robot.txt file suggests that all bots are prohibited from accessing or scraping both the /lyricsdb/ and /song/ directory. The robot.txt file also specifies a certain user agent that is not allowed to scrape any part of the website. This means that the scraping that is about to be performed is allowed as the content will come from the root directory or other areas that are not explicitly stated as disallowed.

# %%
# Let's set up a dictionary of lists to hold our links
lyrics_pages = defaultdict(list)

for artist, artist_page in artists.items() :
    # request the page and sleep
    r = requests.get(artist_page)
    time.sleep(5 + 10*random.random())

     # use BeautifulSoup to parse the page
    soup = BeautifulSoup(r.content, 'html.parser')

    # now extract the links to lyrics pages from this page
    for link in soup.find_all('a', href=True):
        if '/lyrics/' in link['href']:  # lyrics links path that contain "/lyrics/"
            full_link = requests.compat.urljoin(artist_page, link['href'])  # construct full URL
            lyrics_pages[artist].append(full_link)  # store the links where the key is the artist and value is a list of links

# %% [markdown]
# Let's make sure we have enough lyrics pages to scrape.

# %%
for artist, lp in lyrics_pages.items() :
    assert(len(set(lp)) > 20)

# %%
# Let's see how long it's going to take to pull these lyrics 
# if we're waiting `5 + 10*random.random()` seconds 
for artist, links in lyrics_pages.items() : 
    print(f"For {artist} we have {len(links)} links.")
    print(f"The full pull will take for this artist will take {round(len(links)*10/3600,2)} hours.")
# Out:
# For one direction we have 112 links.
# The full pull will take for this artist will take 0.31 hours.
# For sabrina carpenter we have 115 links.
# The full pull will take for this artist will take 0.32 hours.

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
start = time.time()

# Function to generate a valid filename from a URL
def generate_filename_from_url(url):
    return url.split('/')[-1].replace('.html', '').replace('-', '_') + '.txt'

# Create main 'lyrics' directory
if not os.path.exists('lyrics'):
    os.makedirs('lyrics')

# Iterate over the artists
for artist, pages in lyrics_pages.items():
    
    # Create a subfolder in 'lyrics' with the artist's name
    artist_folder = os.path.join('lyrics', artist.lower().replace(' ', '_'))
    if not os.path.exists(artist_folder):
        os.makedirs(artist_folder)
    
    # Iterate over the lyrics pages for the artist
    for page_url in pages:
        
        # Request the page and sleep to avoid overwhelming the server
        r = requests.get(page_url)
        time.sleep(5 + 10 * random.random())
        
        # Parse the HTML page with BeautifulSoup
        soup = BeautifulSoup(r.content, 'html.parser')
        
        # Extract lyrics from the HTML - identify the correct tag or class where the lyrics are stored with inspect element
        lyrics = soup.find('div', class_='col-xs-12 col-lg-8 text-center').get_text(separator='\n').strip()  # Adjust class name based on website structure

        # Generate the filename based on the URL of the lyrics page
        filename = generate_filename_from_url(page_url)
        
        # Write the lyrics to a text file in the artist's subfolder
        filepath = os.path.join(artist_folder, filename)
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(lyrics)
            
        print(f"Saved lyrics for {artist} to {filepath}")
# Out:
# Saved lyrics for one direction to lyrics\one_direction\whatmakesyoubeautiful.txt
# Saved lyrics for one direction to lyrics\one_direction\gottabeyou.txt
# Saved lyrics for one direction to lyrics\one_direction\onething.txt
# Saved lyrics for one direction to lyrics\one_direction\morethanthis.txt
# Saved lyrics for one direction to lyrics\one_direction\upallnight.txt
# Saved lyrics for one direction to lyrics\one_direction\iwish.txt
# Saved lyrics for one direction to lyrics\one_direction\tellmealie.txt
# Saved lyrics for one direction to lyrics\one_direction\taken.txt
# Saved lyrics for one direction to lyrics\one_direction\iwant.txt
# Saved lyrics for one direction to lyrics\one_direction\everythingaboutyou.txt
# Saved lyrics for one direction to lyrics\one_direction\samemistakes.txt
# Saved lyrics for one direction to lyrics\one_direction\saveyoutonight.txt
# Saved lyrics for one direction to lyrics\one_direction\stolemyheart.txt
# Saved lyrics for one direction to lyrics\one_direction\standup.txt
# Saved lyrics for one direction to lyrics\one_direction\moments.txt
# Saved lyrics for one direction to lyrics\one_direction\foreveryoung.txt
# Saved lyrics for one direction to lyrics\one_direction\livewhilewereyoung.txt
# Saved lyrics for one direction to lyrics\one_direction\kissyou.txt
# Saved lyrics for one direction to lyrics\one_direction\littlethings.txt
# Saved lyrics for one direction to lyrics\one_direction\cmoncmon.txt
# Saved lyrics for one direction to lyrics\one_direction\lastfirstkiss.txt
# Saved lyrics for one direction to lyrics\one_direction\heartattack.txt
# Saved lyrics for one direction to lyrics\one_direction\rockme.txt
# Saved lyrics for one direction to lyrics\one_direction\changemymind.txt
# Saved lyrics for one direction to lyrics\one_direction\iwould.txt
# Saved lyrics for one direction to lyrics\one_direction\overagain.txt
# Saved lyrics for one direction to lyrics\one_direction\backforyou.txt
# Saved lyrics for one direction to lyrics\one_direction\theydontknowaboutus.txt
# Saved lyrics for one direction to lyrics\one_direction\summerlove.txt
# Saved lyrics for one direction to lyrics\one_direction\shesnotafraid.txt
# Saved lyrics for one direction to lyrics\one_direction\lovedyoufirst.txt
# Saved lyrics for one direction to lyrics\one_direction\nobodycompares.txt
# Saved lyrics for one direction to lyrics\one_direction\stilltheone.txt
# Saved lyrics for one direction to lyrics\one_direction\trulymadlydeeply.txt
# Saved lyrics for one direction to lyrics\one_direction\magic.txt
# Saved lyrics for one direction to lyrics\one_direction\irresistible.txt
# Saved lyrics for one direction to lyrics\one_direction\bestsongever.txt
# Saved lyrics for one direction to lyrics\one_direction\storyofmylife.txt
# Saved lyrics for one direction to lyrics\one_direction\diana.txt
# Saved lyrics for one direction to lyrics\one_direction\midnightmemories.txt
# Saved lyrics for one direction to lyrics\one_direction\youi.txt
# Saved lyrics for one direction to lyrics\one_direction\dontforgetwhereyoubelong.txt
# Saved lyrics for one direction to lyrics\one_direction\strong.txt
# Saved lyrics for one direction to lyrics\one_direction\happily.txt
# Saved lyrics for one direction to lyrics\one_direction\rightnow.txt
# Saved lyrics for one direction to lyrics\one_direction\littleblackdress.txt
# Saved lyrics for one direction to lyrics\one_direction\throughthedark.txt
# Saved lyrics for one direction to lyrics\one_direction\somethinggreat.txt
# Saved lyrics for one direction to lyrics\one_direction\littlewhitelies.txt
# Saved lyrics for one direction to lyrics\one_direction\betterthanwords.txt
# Saved lyrics for one direction to lyrics\one_direction\whydontwegothere.txt
# Saved lyrics for one direction to lyrics\one_direction\doesheknow.txt
# Saved lyrics for one direction to lyrics\one_direction\alive.txt
# Saved lyrics for one direction to lyrics\one_direction\halfaheart.txt
# Saved lyrics for one direction to lyrics\one_direction\stealmygirl.txt
# Saved lyrics for one direction to lyrics\one_direction\readytorun.txt
# Saved lyrics for one direction to lyrics\one_direction\wheredobrokenheartsgo.txt
# Saved lyrics for one direction to lyrics\one_direction\18.txt
# Saved lyrics for one direction to lyrics\one_direction\girlalmighty.txt
# Saved lyrics for one direction to lyrics\one_direction\foolsgold.txt
# Saved lyrics for one direction to lyrics\one_direction\nightchanges.txt
# Saved lyrics for one direction to lyrics\one_direction\nocontrol.txt
# Saved lyrics for one direction to lyrics\one_direction\fireproof.txt
# Saved lyrics for one direction to lyrics\one_direction\spaces.txt
# Saved lyrics for one direction to lyrics\one_direction\stockholmsyndrome.txt
# Saved lyrics for one direction to lyrics\one_direction\clouds.txt
# Saved lyrics for one direction to lyrics\one_direction\changeyourticket.txt
# Saved lyrics for one direction to lyrics\one_direction\illusion.txt
# Saved lyrics for one direction to lyrics\one_direction\onceinalifetime.txt
# Saved lyrics for one direction to lyrics\one_direction\actmyage.txt
# Saved lyrics for one direction to lyrics\one_direction\heyangel.txt
# Saved lyrics for one direction to lyrics\one_direction\dragmedown.txt
# Saved lyrics for one direction to lyrics\one_direction\perfect.txt
# Saved lyrics for one direction to lyrics\one_direction\infinity.txt
# Saved lyrics for one direction to lyrics\one_direction\endoftheday.txt
# Saved lyrics for one direction to lyrics\one_direction\ificouldfly.txt
# Saved lyrics for one direction to lyrics\one_direction\longwaydown.txt
# Saved lyrics for one direction to lyrics\one_direction\neverenough.txt
# Saved lyrics for one direction to lyrics\one_direction\olivia.txt
# Saved lyrics for one direction to lyrics\one_direction\whatafeeling.txt
# Saved lyrics for one direction to lyrics\one_direction\loveyougoodbye.txt
# Saved lyrics for one direction to lyrics\one_direction\iwanttowriteyouasong.txt
# Saved lyrics for one direction to lyrics\one_direction\history.txt
# Saved lyrics for one direction to lyrics\one_direction\temporaryfix.txt
# Saved lyrics for one direction to lyrics\one_direction\walkinginthewind.txt
# Saved lyrics for one direction to lyrics\one_direction\wolves.txt
# Saved lyrics for one direction to lyrics\one_direction\am.txt
# Saved lyrics for one direction to lyrics\one_direction\home.txt
# Saved lyrics for one direction to lyrics\one_direction\alreadyhome.txt
# Saved lyrics for one direction to lyrics\one_direction\anotherworld.txt
# Saved lyrics for one direction to lyrics\one_direction\bestsongevermusicvideoversion.txt
# Saved lyrics for one direction to lyrics\one_direction\dragmedownbigpaynoxafterhrsremix.txt
# Saved lyrics for one direction to lyrics\one_direction\fourfiveseconds.txt
# Saved lyrics for one direction to lyrics\one_direction\grenade.txt
# Saved lyrics for one direction to lyrics\one_direction\halftheworldaway.txt
# Saved lyrics for one direction to lyrics\one_direction\ishouldhavekissedyou.txt
# Saved lyrics for one direction to lyrics\one_direction\imyours.txt
# Saved lyrics for one direction to lyrics\one_direction\justcantlethergo.txt
# Saved lyrics for one direction to lyrics\one_direction\nanana.txt
# Saved lyrics for one direction to lyrics\one_direction\nandossong.txt
# Saved lyrics for one direction to lyrics\one_direction\onewayoranotherteenagekicks.txt
# Saved lyrics for one direction to lyrics\one_direction\onlygirlintheworld.txt
# Saved lyrics for one direction to lyrics\one_direction\teenagedirtbag.txt
# Saved lyrics for one direction to lyrics\one_direction\thatswhatmakesus1d.txt
# Saved lyrics for one direction to lyrics\one_direction\torn.txt
# Saved lyrics for one direction to lyrics\one_direction\usesomebody.txt
# Saved lyrics for one direction to lyrics\one_direction\valerie.txt
# Saved lyrics for one direction to lyrics\one_direction\vashappeninboys.txt
# Saved lyrics for one direction to lyrics\one_direction\whatmakesuuseful.txt
# Saved lyrics for one direction to lyrics\one_direction\whereweare.txt
# Saved lyrics for one direction to lyrics\one_direction\wonderwall.txt
# Saved lyrics for one direction to lyrics\one_direction\yourmathskillsareterrible.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\eyeswideopen.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\cantblameagirlfortrying.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\middleofstartingover.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\wellbethestars.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\twoyounghearts.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\yourloveslike.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\tooyoung.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\seamless.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\rightnow.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\darlingimamess.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\whiteflag.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\bestthingigot.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\onpurpose.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\feelslikeloneliness.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\thumbs.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\nowords.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\runandhide.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\mirage.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\dontwantitback.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\shadows.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\space.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\allwehaveislove.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\almostlove.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\paris.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\holdtight.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\sueme.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\prfct.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\badtime.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\monalisa.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\diamondsareforever.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\inmybed.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\pushing20.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\icantstopme.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\imfakin.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\takeoffallyourcool.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\tellem.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\exhale.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\takeyouback.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\lookingatme.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\alien.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\emailsicantsend.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\vicious.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\readyourmind.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\tornadowarnings.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\becauseilikedaboy.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\alreadyover.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\howmanythings.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\betuwanna.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\nonsense.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\fasttimes.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\skinnydipping.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\badforbusiness.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\decode.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\opposite.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\feather.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\lonesome.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\thingsiwishyousaid.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\anonsensechristmas.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\buymepresents.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\santadoesntknowyoulikeido.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\cindylouwho.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\isitnewyearsyet.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\whitexmas.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\taste.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\pleasepleaseplease.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\goodgraces.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\sharpesttool.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\coincidence.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\bedchem.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\espresso.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\dumbpoetic.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\slimpickins.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\juno.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\lietogirls.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\dontsmile.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\needlesstosay.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\busywoman.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\almostlover3habremix.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\almostloveremix.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\alonetogether.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\blueberries.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\catchmybreath.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\christmasthewholeyearround.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\clouds.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\espressomarkronsonxfnzworkinglateremix.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\espressomarkronsonxfnzworkinglaterremix.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\fallapart.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\fixmeup.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\haveyourselfamerrylittlechristmas.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\hello.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\honeymoonfades.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\howtogotoconfession.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\iknewyouweretrouble.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\istillhaventfoundwhatimlookingfor.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\itsfinallychristmas.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\letmemoveyou.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\lieforlove.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\likerealpeopledo.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\newrules.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\nonsenseremix.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\onmyway.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\rescueme.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\safeandsound.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\signofthetimes.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\silvernights.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\skin.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\smile.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\smokeandfire.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\standout.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\takeontheworld.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\thinkingoutloud.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\tomorrowstartstoday.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\werethebabysitters.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\why.txt
# Saved lyrics for sabrina carpenter to lyrics\sabrina_carpenter\wildside.txt

# %%
# Check the contents of saved file to ensure correct class is pulled 
# Function to view the contents of a saved file
def view_lyrics(artist, filename):
    artist_folder = os.path.join('lyrics', artist.lower().replace(' ', '_'))
    filepath = os.path.join(artist_folder, filename)
    
    if os.path.exists(filepath):
        with open(filepath, 'r', encoding='utf-8') as f:
            contents = f.read()
            print(contents)  # Print the file's contents to the console
    else:
        print(f"File {filepath} not found.")

# Example usage: View the lyrics for a particular artist and file
view_lyrics('one_direction', 'onething.txt')  # Replace with actual artist and file
# Out:
# "One Thing" lyrics
#
#
#
#
# One Direction Lyrics
#
#
#
#
#
#
#
#
#
#
# "One Thing"
#
#
#
#
#
#
#
#
# [Liam:]
#
# I've tried playing it cool
#
# But when I'm looking at you
#
# I can't ever be brave
#
# 'Cause you make my heart race
#
#
#
#
# [Harry:]
#
# Shot me out of the sky
#
# You're my kryptonite
#
# You keep making me weak
#
# Yeah, frozen and can't breathe
#
#
#
#
# [Zayn:]
#
# Something's gotta give now
#
# 'Cause I'm dying just to make you see
#
# That I need you here with me now
#
# 'Cause you've got that one thing
#
#
#
#
# [Chorus:]
#
# So get out, get out, get out of my head
#
# And fall into my arms instead
#
# I don't, I don't, don't know what it is
#
# But I need that one thing
#
# And you've got that one thing
#
#
#
#
# [Niall:]
#
# Now I'm climbing the walls
#
# But you don't notice at all
#
# That I'm going out of my mind
#
# All day and all night
#
#
#
#
# [Louis:]
#
# Something's gotta give now
#
# 'Cause I'm dying just to know your name
#
# And I need you here with me now
#
# 'Cause you've got that one thing
#
#
#
#
# [Chorus:]
#
# So get out, get out, get out of my head
#
# And fall into my arms instead
#
# I don't, I don't, don't know what it is
#
# But I need that one thing
#
#
#
# So get out, get out, get out of my mind
#
# And come on, come into my life
#
# I don't, I don't, don't know what it is
#
# But I need that one thing
#
# And you've got that one thing
#
#
#
# Woah-oh-oh-oh
#
# Woah-oh-oh-oh
#
# Woah-oh-oh-oh
#
#
#
#
# [Harry:]
#
# You've got that one thing
#
#
#
#
# [Liam:]
#
# Get out, get out, get out of my head
#
# And fall into my arms instead
#
#
#
#
# [Chorus:]
#
# So get out, get out, get out of my head
#
# And fall into my arms instead
#
# I don't, I don't, don't know what it is
#
# But I need that one thing
#
#
#
# So get out, get out, get out of my mind (out of my mind)
#
# And come on, come into my life
#
# I don't, I don't, don't know what it is
#
# But I need that one thing
#
# Yeah, you've got that one thing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Submit Corrections
#
#
#
#
# Thanks to Yullin Leow, maila, anissa, Jenni!, kristyna, Hayley for correcting these lyrics.
#
#
#
#
#
#
#
#
#
#
#
#
# Writer(s): Savan Kotecha, Rami Yacoub, Carl Falk
#
#
#
#
#
#
#
#
#
# This song was released as the album's third single in the UK on the 13th of February 2012, and as the second single in the USA and other countries.
#
#
#
#
# Savan Kotecha and producers Carl Falk and Rami Yacoub created this track by merging two different upbeat pop-rock songs they wrote beforehand. Falk noted in a 2012 interview with Examiner.com that "one had a really, really good verse" and the other track "had a really, really good chorus".
#
#
#
#
#
# The song has been certified "Platinum" by the Recording Industry Association of America for shipments of one million copies.
#
#
#
#
# Some say that the song is musically similar to the
# Backstreet Boys
#  song
# "I Want It That Way"
# .
#
#
#
#
# The
# music video
#  that accompanies this track shows One Direction performing in London.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AZLyrics
#
#
# O
#
#
# One Direction Lyrics
#
#
#
#
#
#
#
#
# album:
# "Up All Night"
#  (2011)
#
#
# What Makes You Beautiful
#
#
#
# Gotta Be You
#
#
#
# One Thing
#
#
#
# More Than This
#
#
#
# Up All Night
#
#
#
# I Wish
#
#
#
# Tell Me A Lie
#
#
#
# Taken
#
#
#
# I Want
#
#
#
# Everything About You
#
#
#
# Same Mistakes
#
#
#
# Save You Tonight
#
#
#
# Stole My Heart
#
#
#
# Stand Up
#
# (Limited Edition Bonus Track)
#
#
# Moments
#
# (Limited Edition Bonus Track)
#
#
# Forever Young
#
# (Limited Edition Bonus Track)
#
#
#
#
#
#
#
#
# You May Also Like
#
#
# Justin Bieber - "Beauty And A Beat"
#
#  Yeah
# Young Money
# Nicki Minaj
# Justin, rrr Show you off
# Tonight, I wanna show you off (Ay-ay-ay)
# What you got
# A billion could've never bought (Ay-ay-ay)
#
# We gonna party like it's 3012 tonight
# I wanna...
#
#
# The Vamps - "Oh Cecilia (Breaking My Heart)"
#
# Cecilia, you're breaking my heart
# You're shaking my confidence daily
#
# Put your hands up
# You're surrounded
# The whole love thing
# I clowned it
# Then who's the joker?
# I guess I'm it
# 'Cause I let it right...
#
#
# Austin Mahone - "All I Ever Need"
#
# Don't the water grow the trees
# Don't the moon pull the tide
# Don't the stars light the sky
# Like you need to light my life
# If you need me anytime
# You know I'm always right by your side
# See I've never...
#
#
# Little Mix - "Black Magic"
#
# All the girls on the block knocking at my door!
# Wanna know what it is make the boys want more! Is your lover playing on your side?
# Said he loves you,
# But he ain't got time.
# Here's the answer.
# Come...
#
#
# HRVY - "Personal"
#
# I don't know why'd you do this to me
# You're so cold
# You'd be playing like
# Yeah yeah yeah yeah yeah yeah yeah yeah yeah
# I got told danger follows everywhere you go
# But I still be like
# Yeah yeah yeah...
#
#
#
#
#
#
#
#
#
#
#
#
#  Search

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")
# Out:
# Total run time was 0.74 hours.

# %% [markdown]
# ---
#
# # Evaluation
#
# This assignment asks you to pull data by scraping www.AZLyrics.com.  After you have finished the above sections , run all the cells in this notebook. Print this to PDF and submit it, per the instructions.

# %%
# Simple word extractor from Peter Norvig: https://norvig.com/spell-correct.html
def words(text): 
    return re.findall(r'\w+', text.lower())

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
# Out:
# For one_direction we have 112 files.
# For one_direction we have roughly 78680 words, 4192 are unique.
# For sabrina_carpenter we have 115 files.
# For sabrina_carpenter we have roughly 78616 words, 4768 are unique.
